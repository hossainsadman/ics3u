# %%
from math import sin, cos, tan
from math import asin, acos, atan
from math import degrees, radians

# new trig functions for degrees
def sin_(x):
    return sin(radians(x))

def cos_(x):
    return cos(radians(x))

def tan_(x):
    return tan(radians(x))

def asin_(x):
    return degrees(asin(x))

def acos_(x):
    return degrees(acos(x))

def atan_(x):
    return degrees(atan(x))

# %%
'''
Try to reproduce this table (of course, not by cutting and pasting!):
              30        45        60

sin       0.5000    0.7071    0.8660

cos       0.8660    0.7071    0.5000

tan       0.5774    1.0000    1.7321    

Hint: use the built in round() function, or of course format the string
'''

# %%
print("{:{w}}{:{w}}{:{w}}".format("30", "45", "60", w=8))
print("{:{w}}{:{w}}{:{w}}{:{w}}".format("sin", round(sin_(30),4), round(sin_(45),4), round(sin_(60),4), w = 4))
# Out:
# 30      45      60
# sin  0.50.70710.866

# %%
'''
Design a simple menu-based trigonometry calculator (in degrees).
a. menu options: sin, cos, tan, arcsin, arccos, arctan, exit
b. should round ratios to four decimal places and angles to one decimal place
c. OPTIONAL: add menu options for csc, sec, cot, and a unit converter (deg ↔ rad)
d. CHALLENGE: catch ALL exceptions, i.e. what would asin(2) give?
'''
