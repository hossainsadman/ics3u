# %%
from fractions import Fraction

#  Exercise 1
a = Fraction(1,2)
b = Fraction(2,3)
c = Fraction(4,5)
d = Fraction(3,7)

print(a+b)
print(c-d)
print(b**2)
print(b*c)
print(b/a)
# Out:
# 7/6
# 13/35
# 4/9
# 8/15
# 4/3

# %%
from fractions import Fraction

#  Exercise 2
def get_frac(msg) -> Fraction:
  try:
    fraction = Fraction(input(msg))
    return fraction
  except:
    return get_frac(msg)

# %%
from fractions import Fraction

#  Exercise 3
def get_int(msg: str, error_msg: str) -> int:
  try:
    integer = int(input(msg))
    if not 1 <= integer <= 5:
      print(error_msg)
      return get_int(msg, error_msg)
    else:
      return integer
  except ValueError:
    print(error_msg)
    return get_int(msg, error_msg)

def print_title(msg):
  line = "-" * len(msg)
  print(line)
  print(msg)
  print(line)

def get_menu():
  menu = ""
  menu += "Please choose from one of the following menu options:\n"
  menu += "1. Add.\n"
  menu += "2. Subtract.\n"
  menu += "3. Multiply.\n"
  menu += "4. Divide.\n"
  menu += "5. Exit.\n"
  return menu

# def calc():

print_title("Calculatron 3000")
menu = get_menu()
option = get_int(menu + "\n> ", "\nInvalid input. Try again.\n")
if option == 5:
  print("Thanks for using this program!")
else:
  a = get_frac("Enter first fraction: ")
  b = get_frac("Enter second fraction: ")
  if option == 1:
    calc = a + b
  elif option == 2:
    calc = a - b
  elif option == 3:
    calc = a * b
  elif option == 4:
    calc = a / b
  print(calc)
# Out:
# ----------------
# Calculatron 3000
# ----------------
# Please choose from one of the following menu options:
# 1. Add.
# 2. Subtract.
# 3. Multiply.
# 4. Divide.
# 5. Exit.
#
# > 3
# Enter first fraction: 1/2
# Enter second fraction: 1/2
# 1/4
